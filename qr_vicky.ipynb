# %%
import qrcode
data=input("enter the text or url for which you want to create a QR code:")
qr=qrcode.make(data)
qr.save("my_qr.png")
print("qr code successfully generated!")
# Out:
# enter the text or url for which you want to create a QR code: https://www.instagram.com/vicky_creativ_art?igsh=eG5kZ2kwN2tkMTI=&utm_source=ig_contact_invite
# qr code successfully generated!

# %%
from IPython.display import Image
Image("my_qr.png")
